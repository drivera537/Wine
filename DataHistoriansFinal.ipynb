# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
from config import params, base_url
# %matplotlib notebook
# Out:
# https://maps.googleapis.com/maps/api/geocode/json

# %%
# Dependencies
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
from config import params, base_url

def wine_dropna(wine_data, col): 
    wine_data.dropna(subset=[col], inplace = True)
    print("wine_data size, after dropping NaN for "+ col + ": " + str(wine_data.shape))

def get_country_data(data, country): 
    ret_df = data.loc[data['country'] == country].copy()
    if ret_df.shape[0] > 0: 
        print('Record count for Country, ' + str(country) + ': ' + str(ret_df.shape))
        return ret_df
    else: 
        return None

def get_g_address(winery_geo): 

    formatted_address = winery_geo["results"][0]['formatted_address']
    formed_address_list = winery_geo["results"][0]['address_components']
    try: 
        street_number = formed_address_list[0]['long_name']
        route = formed_address_list[1]['long_name']
        locality = formed_address_list[2]['long_name']
        administrative_area_level_2 = formed_address_list[3]['long_name']
        administrative_area_level_1 = formed_address_list[4]['long_name']
        g_country = formed_address_list[5]['long_name']
        postal_code = formed_address_list[6]['long_name']
    except: 
        return None
    
    ret_data = (formatted_address, formed_address_list, 
                street_number, route, locality, 
                administrative_area_level_2, 
                administrative_area_level_1, 
                g_country, 
                postal_code)
    return ret_data

def check_match(formed_address, province, country): 
    return country != formed_address[7] or province != formed_address[5]

def write_results(out_path, content): 
    out_dir_name = os.path.dirname(out_path)

    if not os.path.exists(out_dir_name): 
        os.mkdir(out_dir_name, 511)
    file_name = os.path.split(out_path)[1]
    
    with open(os.path.join(out_dir_name, file_name), 'a') as ctx: 
        ctx.write(content)

wine_data = pd.read_csv('Data/winemag-data-130k-v2.csv')
wine_data.head()

cleaned_wine_data_ind_cntrs = wine_data.copy()
cleaned_wine_data_all_cntrs = wine_data.copy()

non_nullable_colums_for_individual_countries = [
                       'title', 
                       'price', 
                       'points',
                       'winery',  
                       'taster_name', 
                       'region_1'
                      ]

non_nullable_colums_for_all_countries = [
                       'title', 
                       'price', 
                       'points',
                       'winery',  
                       'taster_name'
                      ]

countries = list(cleaned_wine_data_ind_cntrs.country.unique())

print(countries)
print(len(countries))

for cols in non_nullable_colums_for_individual_countries: 
    wine_dropna(cleaned_wine_data_ind_cntrs, cols)
    
for cols in non_nullable_colums_for_all_countries: 
    wine_dropna(cleaned_wine_data_all_cntrs, cols)

data_columns_for_study = ['title', 'description', # Wine
                          'taster_name', 'taster_twitter_handle', 'points', 'price', # Rating
                          'variety', 'winery', # Wine Type
                          'province', 'region_1', 'country' # Area
                         ]
cleaned_wine_data_ind_cntrs = cleaned_wine_data_ind_cntrs[data_columns_for_study]
cleaned_wine_data_all_cntrs = cleaned_wine_data_all_cntrs[data_columns_for_study]

country_data = pd.DataFrame()
print(base_url)
unfound_winery = [{}]
for country in countries: 
    country_data = get_country_data(cleaned_wine_data_ind_cntrs, country)
    
    if isinstance(country_data, pd.DataFrame):
        if (country == 'Australia'): 
            print(country)
            country_data['latitude'] = ''
            country_data['longitude'] = ''
            country_data['g_address'] = ''
            country_data.index = pd.RangeIndex(len(country_data.index))
            address_dict = {}
            for index, row in country_data.iterrows(): 
                print(index)
                winery_address = f"{row['winery']} winery, {row['region_1']}, {row['province']}, {row['country']}"
                if not winery_address in address_dict.keys(): 
                    address_dict.update({winery_address: []})
                    params['address'] = winery_address
                    response = requests.get(base_url, params=params)
                    # print(response)
                    if response.status_code == 200:
                    # Extracting data in json format
                        winery_geo = response.json()
                        if winery_geo.get("results", []):
                            lat = winery_geo["results"][0]["geometry"]["location"]["lat"]
                            lon = winery_geo["results"][0]["geometry"]["location"]["lng"]
                        else: 
                            unfound_winery.append({'winery_address': f"{row['winery']} winery, {row['region_1']}, {row['province']}, {row['country']}"})
                            country_data.drop([index])
                            address_dict.pop(winery_address)
                            continue
                    formed_address = get_g_address(winery_geo)
                    if formed_address == None: 
                        unfound_winery.append({'winery_address': f"{row['winery']} winery, {row['region_1']}, {row['province']}, {row['country']}"})
                        country_data.drop([index])
                        address_dict.pop(winery_address)
                        continue
                    check_match_count = 0
                    is_winery_add_found = True
                    while not check_match(formed_address, row['province'], country): 
                        check_match_count += 1
                        params['address'] = f"{row['region_1']}, {row['province']}, {row['country']}"
                        response = requests.get(base_url, params=params)
                        winery_geo = response.json()
                        formed_address = get_g_address(winery_geo)
                        if check_match_count > 1: 
                            unfound_winery.append({'winery_address': f"{row['winery']} winery, {row['region_1']}, {row['province']}, {row['country']}"})
                            country_data.drop([index])
                            is_winery_add_found = False
                            address_dict.pop(winery_address)
                            break
                    if not is_winery_add_found: 
                        continue

                    formed_address = f'{formed_address[2]}~~~~{formed_address[3]}~~~~{formed_address[4]}~~~~{formed_address[5]}~~~~{formed_address[6]}~~~~{formed_address[7]}~~~~{formed_address[8]}'
                    
                    address_dict[winery_address] = [lat, lon, formed_address]
                    country_data.at[index, 'latitude'] = str(lat)
                    country_data.at[index, 'longitude'] = str(lon)
                    country_data.at[index, 'g_address'] = str(formed_address)
                    # print(f"Winery: {winery_address} ; LAT: {lat} ; LON: {lon}; Address: {formed_address}")
                else: 
                    lat = address_dict[winery_address][0]
                    lon = address_dict[winery_address][1]
                    formed_address = address_dict[winery_address][2]
                    country_data.at[index, 'latitude'] = str(lat)
                    country_data.at[index, 'longitude'] = str(lon)
                    country_data.at[index, 'g_address'] = str(formed_address)
            print(country_data.shape)
            country_data['g_address'].replace('', np.nan, inplace=True)
            wine_dropna(country_data, 'g_address')
            print(country_data.shape)
            country_data.to_excel('output.xlsx', sheet_name=country, float_format="%.12f")
    else: 
        continue
    
# print('--------------------------------------')
# for country in countries: 
#     country_data = get_country_data(cleaned_wine_data_all_cntrs, country)

print(unfound_winery)

# %%
countries = ['Australia', 'Canada', 'France', 'Italy', 'Spain', 'US']
comparison_data = {}
bar_data = {}
x_axis = np.arange(len(countries))
colors = ['r', 'g', 'b', 'y', 'm', 'c']
bar_width = 0.25
alp = 0.3
x_axis
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
for index, country in enumerate(countries): 
    datatrame_list = []
    file_name = 'output_' + country + '.xlsx'
    c_data = pd.read_excel(file_name)
    
    c_data = c_data.rename(index= str, columns={'title':'Title', 'description': 'Description',
                                                'taster_name': 'Sommelier', 'taster_twitter_handle':'Sommelier Twitter Acc.',
                                                'points': 'Points', 'price':"Price", 'variety': 'Variety', 'winery': 'Winery',
                                                'province':'State', 'region_1': 'County', 'latitude': 'Lat', 'longitude': "Lng",
                                                'g_address': 'Address'})
    
    winery_max_price = c_data.groupby(['Variety'])['Price'].max().to_frame()

    winery_max_points = c_data.groupby(['Variety'])['Points'].max().to_frame()
    
    winery_competitive_score = winery_max_price.merge(winery_max_points, how = 'inner', on = 'Variety')
    
    winery_competitive_score['Ratio'] = winery_competitive_score['Points'] / winery_competitive_score['Price']
    
    winery_competitive_score = winery_competitive_score.sort_values(by = 'Ratio', ascending = False)
    
    datatrame_list.append(winery_competitive_score)
    
    
    ratio_data = winery_competitive_score.reset_index()['Ratio'].tolist()
    ratio_data = [round(float(x), 2) for x in ratio_data[0:3]]
    print(f'{country}: {ratio_data}')
    bar_data[country] = ratio_data
    
    
    median_price_by_winery_variety_df = c_data.groupby(['Winery', 'Variety'])['Price'].median().to_frame()
    
    median_price_by_winery_variety_df = median_price_by_winery_variety_df.sort_values(by=["Price"], ascending = False)
    
    
    datatrame_list.append(median_price_by_winery_variety_df)
    
    comparison_data.update({country: datatrame_list})
# Out:
# Australia: [6.77, 5.93, 5.87]
# Canada: [6.92, 5.06, 4.74]
# France: [9.44, 8.6, 7.73]
# Italy: [7.33, 6.29, 6.14]
# Spain: [12.14, 10.62, 8.4]
# US: [8.6, 7.33, 6.77]

# %%
# for k, v_list in comparison_data.items(): 
#     print(k)
#     print('------------------')
#     print(v_list[0].head())

# country_df = {
#     "usa" : [df1]
# }
        
# print(len(comparison_data))
for df in comparison_data:
#     print(len(comparison_data[df]))
    print(df)
    print("------------------------------------")
    for index in range(len(comparison_data[df])):
        print(comparison_data[df][index])
        print("------------------------------------")
# Out:
# Australia
# ------------------------------------
#                                   Price  Points     Ratio
# Variety
# Port                                 13      88  6.769231
# Shiraz-Mourvèdre                     15      89  5.933333
# Savagnin                             15      88  5.866667
# Verdelho                             15      88  5.866667
# Vermentino                           16      86  5.375000
# Moscato                              17      88  5.176471
# Mourvèdre-Syrah                      18      92  5.111111
# Chardonnay-Semillon                  18      89  4.944444
# Sangiovese                           18      88  4.888889
# Cabernet Sauvignon-Merlot-Shiraz     20      91  4.550000
# Tempranillo                          20      89  4.450000
# Petit Verdot                         20      88  4.400000
# Shiraz-Malbec                        25      92  3.680000
# Sauvignon Blanc                      25      92  3.680000
# Pinot Gris                           25      89  3.560000
# Zinfandel                            26      88  3.384615
# Rosé                                 28      90  3.214286
# Pinot Grigio                         30      90  3.000000
# Cabernet Sauvignon-Sangiovese        30      88  2.933333
# Sauvignon                            30      88  2.933333
# Durif                                30      84  2.800000
# Marsanne                             33      92  2.787879
# Cabernet Merlot                      32      88  2.750000
# Sauvignon Blanc-Semillon             35      92  2.628571
# Muscat                               35      92  2.628571
# Tokay                                35      91  2.600000
# Grenache-Shiraz                      35      90  2.571429
# Rhône-style White Blend              35      89  2.542857
# White Blend                          38      90  2.368421
# Champagne Blend                      40      92  2.300000
# G-S-M                                40      92  2.300000
# Semillon-Sauvignon Blanc             39      89  2.282051
# Rhône-style Red Blend                40      91  2.275000
# Shiraz-Cabernet Sauvignon            42      93  2.214286
# Petite Sirah                         42      92  2.190476
# Viognier                             60      93  1.550000
# Marsanne-Roussanne                   60      89  1.483333
# Riesling                             65      93  1.430769
# Shiraz-Grenache                      65      92  1.415385
# Sémillon                             67      93  1.388060
# Cabernet Sauvignon-Merlot            70      91  1.300000
# Cabernet Blend                       75      92  1.226667
# Sparkling Blend                      80      93  1.162500
# Merlot                               86      90  1.046512
# Pinot Noir                           95      93  0.978947
# Mourvèdre                            95      93  0.978947
# Roussanne                           100      91  0.910000
# Bordeaux-style Red Blend            109      93  0.853211
# Red Blend                           125      95  0.760000
# Cabernet Sauvignon-Shiraz           125      94  0.752000
# Mataro                              135      94  0.696296
# Cabernet-Shiraz                     150      96  0.640000
# Grenache                            188      95  0.505319
# Chardonnay                          200      94  0.470000
# Shiraz-Viognier                     225      97  0.431111
# Malbec                              250      91  0.364000
# Syrah                               350      95  0.271429
# Cabernet Sauvignon                  500      95  0.190000
# Shiraz                              850      99  0.116471
# ------------------------------------
#                                                       Price
# Winery                     Variety
# Cloudburst                 Malbec                     250.0
#                            Cabernet Sauvignon         250.0
# Henschke                   Shiraz                     200.0
# Cloudburst                 Chardonnay                 200.0
# Torbreck                   Grenache                   186.5
# Hickinbotham               Cabernet-Shiraz            150.0
# Giaconda                   Chardonnay                 139.5
# Standish                   Shiraz                     135.0
# Jasper Hill                Red Blend                  125.0
# Torbreck                   Shiraz-Viognier            125.0
#                            Shiraz                     115.0
# Clarendon Hills            Syrah                      110.0
# Elderton                   Cabernet Sauvignon         108.0
# Andrew Hardy               Shiraz                     105.0
# Giaconda                   Shiraz                     100.0
# Henschke                   Cabernet Sauvignon         100.0
# Château Tanunda            Shiraz                     100.0
# Giaconda                   Roussanne                  100.0
# Casella                    Cabernet Sauvignon         100.0
# Penfolds                   Shiraz                      99.0
# Cullen                     Bordeaux-style Red Blend    95.0
# Yarra Yering               Pinot Noir                  95.0
#                            Shiraz-Viognier             95.0
# Heartland                  Red Blend                   95.0
# Heathcote Estate           Shiraz                      95.0
# Yeringberg                 Bordeaux-style Red Blend    90.0
# Yarra Yering               Shiraz                      90.0
#                            Bordeaux-style Red Blend    85.0
# Jasper Hill                Shiraz                      85.0
# Apogee                     Sparkling Blend             80.0
# ...                                                     ...
# Penmara                    Chardonnay                  10.5
# Ironberry                  Cabernet Blend              10.0
# Rocland Estate             Chardonnay                  10.0
#                            Rhône-style Red Blend       10.0
# Rolling                    Shiraz                      10.0
# Marlargo                   Red Blend                   10.0
# Yangarra Park              Chardonnay                  10.0
# Andrew Peace               Red Blend                   10.0
# Redbank                    Shiraz                      10.0
# Rocland Estate             Red Blend                   10.0
# Andrew Peace               Shiraz                      10.0
# Jacob's Creek              Shiraz-Cabernet Sauvignon    9.5
# Tatachilla                 Rhône-style Red Blend        9.0
#                            Shiraz                       9.0
# Henry's Drive Vignerons    Chardonnay                   9.0
# Lindemans                  Pinot Noir                   9.0
# Jacob's Creek              Pinot Grigio                 9.0
# Deakin Estate              Moscato                      9.0
# Ironberry                  Red Blend                    9.0
# St. Kilda                  Chardonnay                   9.0
# Rosemount                  Red Blend                    9.0
# Wyndham Estate             Chardonnay                   9.0
# Hardys                     Chardonnay                   9.0
# Yellow Tail                Sauvignon Blanc              8.0
#                            Malbec                       8.0
# Cockatoo Ridge             Shiraz                       8.0
# Beelgara                   Sparkling Blend              8.0
# Jacob's Creek              Moscato                      8.0
# Ballast Stone Estate Wines Merlot                       7.0
# Cockatoo Ridge             Chardonnay                   7.0
#
# [640 rows x 1 columns]
# ------------------------------------
# Canada
# ------------------------------------
#                           Price  Points     Ratio
# Variety
# Gewürztraminer-Riesling      12      83  6.916667
# Muscat                       18      91  5.055556
# Chenin Blanc                 19      90  4.736842
# Moscato                      20      92  4.600000
# Chasselas                    20      90  4.500000
# Pinot Gris                   23      91  3.956522
# White Blend                  23      89  3.869565
# Rosé                         24      90  3.750000
# Gamay Noir                   24      88  3.666667
# Viognier                     25      89  3.560000
# Gewürztraminer               28      92  3.285714
# Sauvignon Blanc              30      91  3.033333
# Malbec                       32      92  2.875000
# Apple                        33      89  2.696970
# Rhône-style White Blend      35      93  2.657143
# Red Blend                    35      92  2.628571
# Cabernet Sauvignon-Syrah     40      88  2.200000
# Cabernet                     40      88  2.200000
# Meritage                     49      93  1.897959
# Pinot Noir                   50      93  1.860000
# Merlot                       50      93  1.860000
# Chardonnay                   50      93  1.860000
# Carmenère                    50      90  1.800000
# Cabernet Merlot              50      89  1.780000
# Vidal                        60      92  1.533333
# Cabernet Sauvignon           70      92  1.314286
# Syrah                        85      94  1.105882
# Vidal Blanc                  85      92  1.082353
# Riesling                     90      94  1.044444
# Cabernet Franc               95      92  0.968421
# Bordeaux-style Red Blend    120      94  0.783333
# ------------------------------------
#                                                 Price
# Winery                Variety
# Wayne Gretzky Estates Cabernet Franc             95.0
# Peller                Cabernet Franc             95.0
# Mission Hill          Bordeaux-style Red Blend   95.0
# Inniskillin           Cabernet Franc             95.0
# Peller                Riesling                   90.0
# Le Vieux Pin          Syrah                      85.0
# Peller                Vidal Blanc                82.5
# Inniskillin           Riesling                   80.0
#                       Vidal Blanc                77.0
# Equifera              Riesling                   70.0
# Stratus               Riesling                   70.0
# Mission Hill          Riesling                   65.0
# Konzelmann            Vidal Blanc                65.0
# Pillitteri            Cabernet Sauvignon         60.0
# Inniskillin           Vidal                      60.0
# Black Hills           Bordeaux-style Red Blend   60.0
# Konzelmann            Cabernet Sauvignon         58.0
# Pillitteri            Cabernet Franc             57.5
# Mission Hill          Vidal                      54.0
# Black Hills           Carmenère                  50.0
# Reif Estate           Merlot                     50.0
#                       Cabernet Merlot            50.0
# Burrowing Owl         Meritage                   49.0
# Foxtrot               Pinot Noir                 47.0
# Pillitteri            Vidal Blanc                45.0
# CedarCreek            Meritage                   45.0
#                       Pinot Noir                 45.0
# Henry of Pelham       Vidal                      45.0
# Foxtrot               Chardonnay                 41.0
# Henry of Pelham       Cabernet                   40.0
# ...                                               ...
# Township 7            Sauvignon Blanc            20.0
# St. Hubertus          Riesling                   20.0
# Calliope              Sauvignon Blanc            20.0
# St. Hubertus          Chasselas                  20.0
# Cellar Hand           Red Blend                  20.0
# Konzelmann            Gewürztraminer             20.0
# LaStella              Moscato                    20.0
# Quails' Gate          Pinot Noir                 20.0
# Cave Spring           Cabernet Franc             20.0
# Nk'Mip Cellars        Merlot                     20.0
# Church & State        Rhône-style White Blend    20.0
# Château des Charmes   Chardonnay                 20.0
# Cave Spring           Pinot Noir                 20.0
# Quails' Gate          Chardonnay                 20.0
# North 42 Degrees      Sauvignon Blanc            19.0
# Quails' Gate          Chenin Blanc               19.0
# Township 7            Gewürztraminer             19.0
# Tinhorn Creek         Pinot Gris                 19.0
# North 42 Degrees      Rosé                       18.0
# Township 7            Rosé                       18.0
# Quails' Gate          Gewürztraminer             18.0
# Colio                 Riesling                   18.0
# Township 7            Muscat                     18.0
# Nk'Mip Cellars        Chardonnay                 17.0
# Tinhorn Creek         Gewürztraminer             17.0
# North 42 Degrees      Riesling                   16.0
# Cellar Hand           White Blend                16.0
# Laughing Stock        Pinot Gris                 15.0
# Château des Charmes   Riesling                   13.0
# Pillitteri            Gewürztraminer-Riesling    12.0
#
# [119 rows x 1 columns]
# ------------------------------------
# France
# ------------------------------------
#                             Price  Points     Ratio
# Variety
# Colombard                       9      85  9.444444
# Chardonnay-Viognier            10      86  8.600000
# Cabernet Sauvignon-Merlot      11      85  7.727273
# Syrah-Grenache                 12      89  7.416667
# Merlot-Cabernet                12      88  7.333333
# Colombard-Sauvignon Blanc      12      85  7.083333
# Picpoul                        13      86  6.615385
# Merlot-Cabernet Sauvignon      14      89  6.357143
# Carignan                       14      89  6.357143
# Sauvignon Gris                 14      87  6.214286
# Abouriou                       15      91  6.066667
# Fer Servadou                   15      87  5.800000
# Semillon-Sauvignon Blanc       15      86  5.733333
# Muscat d'Alexandrie            16      88  5.500000
# Gamay Noir                     16      86  5.375000
# Jacquère                       17      89  5.235294
# Mauzac                         18      90  5.000000
# Altesse                        18      90  5.000000
# Sauvignon Blanc-Chardonnay     18      89  4.944444
# Edelzwicker                    19      90  4.736842
# Mansois                        19      88  4.631579
# Sacy                           19      87  4.578947
# Sémillon                       20      86  4.300000
# Chasselas                      22      90  4.090909
# Mondeuse                       22      89  4.045455
# Pinot Noir-Gamay               23      87  3.782609
# Chenin Blanc-Chardonnay        25      92  3.680000
# Negrette                       25      91  3.640000
# Vermentino                     25      90  3.600000
# Gros Manseng                   25      90  3.600000
# ...                           ...     ...       ...
# Tannat-Cabernet                65      93  1.430769
# Provence red blend             65      92  1.415385
# Merlot                         65      92  1.415385
# White Blend                    70      94  1.342857
# Cabernet Franc                 75      94  1.253333
# Sauvignon Blanc                75      94  1.253333
# Marsanne-Roussanne             74      90  1.216216
# Melon                          80      93  1.162500
# Pinot Blanc                    90      92  1.022222
# Syrah-Viognier                 90      91  1.011111
# Alsace white blend             98      96  0.979592
# Rosé                          100      94  0.940000
# Red Blend                      99      93  0.939394
# Marsanne                      109      92  0.844037
# Riesling                      120      97  0.808333
# Petit Manseng                 128      94  0.734375
# Pinot Gris                    135      96  0.711111
# Viognier                      140      95  0.678571
# Pinot Meunier                 145      94  0.648276
# Chenin Blanc                  159      99  0.622642
# Rhône-style Red Blend         175      98  0.560000
# Gewürztraminer                197      96  0.487310
# Gamay                         224      94  0.419643
# Rhône-style White Blend       253      94  0.371542
# Syrah                         391      94  0.240409
# Champagne Blend               600     100  0.166667
# Chardonnay                    886     100  0.112867
# Bordeaux-style White Blend   1000     100  0.100000
# Pinot Noir                   2500      98  0.039200
# Bordeaux-style Red Blend     3300     100  0.030303
#
# [91 rows x 3 columns]
# ------------------------------------
#                                                               Price
# Winery                           Variety
# Château les Ormes Sorbet         Bordeaux-style Red Blend    3300.0
# Domaine du Comte Liger-Belair    Pinot Noir                  1562.5
# Château Haut-Brion               Bordeaux-style White Blend   800.0
# Château La Mission Haut-Brion    Bordeaux-style White Blend   767.0
# Armand de Brignac                Chardonnay                   675.0
# Château Laville Haut-Brion       Bordeaux-style White Blend   580.0
# Domaine Leflaive                 Chardonnay                   500.5
# Château Cheval Blanc             Bordeaux-style Red Blend     500.0
# Château Latour                   Bordeaux-style Red Blend     456.0
# Armand de Brignac                Champagne Blend              450.0
# Salon                            Chardonnay                   435.0
# Domaine Perrot-Minot             Pinot Noir                   420.0
# Barons de Rothschild             Chardonnay                   390.0
# Louis Latour                     Chardonnay                   380.0
# Château Haut-Brion               Bordeaux-style Red Blend     365.0
# Domaine Henri Rebourseau         Pinot Noir                   320.0
# Clos de Tart                     Pinot Noir                   319.0
# Domaine Méo-Camuzet              Pinot Noir                   307.0
# Perrier Jouët                    Chardonnay                   300.0
# Domaine Jean Grivot              Pinot Noir                   281.0
# Domaine Jean-Michel Gerin        Syrah                        278.5
# Château Clinet                   Bordeaux-style Red Blend     265.0
# Domaine Dujac                    Pinot Noir                   236.0
# Domaine des Lambrays             Pinot Noir                   215.0
# Le Dôme                          Bordeaux-style Red Blend     205.0
# Domaine Jacques Prieur           Pinot Noir                   203.0
# Château La Mission Haut-Brion    Bordeaux-style Red Blend     202.0
# Taittinger                       Chardonnay                   171.0
# M. Chapoutier                    Rhône-style White Blend      164.0
# Château la Fleur-Pétrus          Bordeaux-style Red Blend     162.5
# ...                                                             ...
# Gabriel Meffre                   White Blend                   10.0
# Château Garrineau                Bordeaux-style Red Blend      10.0
# Château des Arnauds              Merlot                        10.0
# Gabriel Meffre                   Sauvignon Blanc               10.0
# Caves Fleury                     Bordeaux-style White Blend    10.0
# Despagne                         Bordeaux-style White Blend    10.0
# Château de la Bouyère            Bordeaux-style Red Blend      10.0
# Château Ducla                    Bordeaux-style Red Blend      10.0
# Domaine Vetriccie                Rosé                          10.0
# Barrière Frères                  Bordeaux-style Red Blend       9.5
# Château Buisson-Redon            Bordeaux-style Red Blend       9.5
# La Vieille Ferme                 Rhône-style White Blend        9.5
# Producteurs Plaimont             Colombard                      9.0
# Les Vignerons de la Méditerranée Sauvignon Blanc                9.0
# Paris-Simoneau                   Sauvignon Blanc                9.0
# Château Macalan                  Bordeaux-style Red Blend       9.0
# Maison de la Villette            Rhône-style Red Blend          9.0
# Producteurs Plaimont             Rosé                           9.0
# Les Vignerons de la Méditerranée Rosé                           9.0
# Confrerie de Oisly et Thesée     Sauvignon Blanc                9.0
# Laroche                          Rosé                           9.0
# Barton & Guestier                Sauvignon Blanc                8.0
# Château de Pennautier            Cabernet Sauvignon             8.0
# Domaine Borie de Maurel          Syrah                          8.0
# L. Tramier & Fils                Red Blend                      8.0
# Val d'Orbieu                     Cabernet Sauvignon             8.0
#                                  Syrah                          8.0
# Château du Cros                  Bordeaux-style White Blend     8.0
# Les Vignerons de la Méditerranée Pinot Noir                     8.0
# Château Labrousse                Bordeaux-style Red Blend       7.5
#
# [2671 rows x 1 columns]
# ------------------------------------
# Italy
# ------------------------------------
#                        Price  Points     Ratio
# Variety
# Prosecco                  12      88  7.333333
# Cabernet                  14      88  6.285714
# Lambrusco Salamino        14      86  6.142857
# Rosé                      15      88  5.866667
# Nuragus                   16      89  5.562500
# Inzolia                   16      88  5.500000
# Nero di Troia             17      86  5.058824
# Caprettone                19      92  4.842105
# Susumaniello              18      87  4.833333
# Torbato                   20      91  4.550000
# Lambrusco                 20      90  4.500000
# Grüner Veltliner          20      90  4.500000
# Coda di Volpe             20      89  4.450000
# Piedirosso                20      88  4.400000
# Uva di Troia              20      87  4.350000
# Moscato Giallo            20      86  4.300000
# Verdeca                   22      90  4.090909
# Trebbiano Spoletino       22      89  4.045455
# Lambrusco Grasparossa     23      91  3.956522
# Freisa                    22      87  3.954545
# Passerina                 22      86  3.909091
# Müller-Thurgau            25      90  3.600000
# Schiava                   25      89  3.560000
# Traminer                  25      89  3.560000
# Molinara                  25      87  3.480000
# Gaglioppo                 25      87  3.480000
# Roviello                  28      93  3.321429
# Insolia                   27      89  3.296296
# Nascetta                  28      90  3.214286
# Prié Blanc                28      89  3.178571
# ...                      ...     ...       ...
# Pinot Grigio              70      91  1.300000
# Viognier                  70      90  1.285714
# Glera                     75      93  1.240000
# Corvina                   75      93  1.240000
# Catarratto                74      88  1.189189
# Aglianico                 80      95  1.187500
# Malvasia Nera             78      89  1.141026
# Primitivo                 80      91  1.137500
# Cabernet Sauvignon        83      93  1.120482
# Barbera                   85      93  1.094118
# Raboso                    80      87  1.087500
# Nero d'Avola              90      94  1.044444
# Cabernet Blend            84      87  1.035714
# Sauvignon Blanc           95      91  0.957895
# Nerello Mascalese        102      95  0.931373
# Ribolla Gialla           115      93  0.808696
# Cabernet Franc           130      97  0.746154
# Picolit                  125      91  0.728000
# Chardonnay               130      94  0.723077
# Marzemino                130      88  0.676923
# White Blend              146      94  0.643836
# Pinot Nero               150      94  0.626667
# Pinot Bianco             165      95  0.575758
# Sparkling Blend          170      94  0.552941
# Carricante               195      95  0.487179
# Syrah                    300      91  0.303333
# Red Blend                500      99  0.198000
# Nebbiolo                 595      99  0.166387
# Merlot                   625      97  0.155200
# Sangiovese               800     100  0.125000
#
# [120 rows x 3 columns]
# ------------------------------------
#                                            Price
# Winery                     Variety
# Masseto                    Merlot          587.5
# Gaja                       Red Blend       500.0
# Tua Rita                   Merlot          400.0
# Gaja                       Nebbiolo        352.5
# Le Macchiole               Merlot          300.0
# Tua Rita                   Syrah           300.0
# Salvioni                   Sangiovese      254.5
# Zymè                       Red Blend       250.0
# Rocca di Frassinello       Merlot          236.0
# Giacomo Conterno           Nebbiolo        225.0
# Tenuta di Trinoro          Merlot          220.0
# Bruno Giacosa              Nebbiolo        200.0
# Biondi Santi               Sangiovese      200.0
# Le Macchiole               Syrah           175.0
# G.A. Rossi di Medelana     Red Blend       160.0
# Elio Grasso                Nebbiolo        160.0
# Sandrone                   Nebbiolo        155.0
# Castello Bonomi            Pinot Nero      150.0
# Vietti                     Nebbiolo        150.0
# Pian delle Vigne           Sangiovese      145.0
# Cantina Bartolo Mascarello Nebbiolo        142.5
# Tenuta di Trinoro          Red Blend       138.0
# Giuseppe Rinaldi           Nebbiolo        137.5
# Poderi Aldo Conterno       Nebbiolo        130.0
# De Stefani                 Marzemino       130.0
# Borgogno                   Nebbiolo        125.0
# Livio Felluga              Picolit         125.0
# Tenuta di Trinoro          Cabernet Franc  120.0
# Olivi                      Merlot          120.0
# Tenuta di Biserno          Red Blend       120.0
# ...                                          ...
# Tenute Orestiadi           Nero d'Avola     10.0
# Nando                      Pinot Grigio     10.0
# Umani Ronchi               Verdicchio       10.0
# Cantina di Gambellara      Garganega        10.0
# Luna Di Luna               White Blend      10.0
# Cabert                     Pinot Grigio     10.0
# Kellerei Kaltern Caldaro   White Blend      10.0
# Tenute Girolamo            Negroamaro       10.0
# Vigneti Zanatta            Cannonau         10.0
# La Carraia                 White Blend      10.0
# Plozner                    Tocai            10.0
# Pierluigi Zampaglione      Fiano            10.0
# Tenute Girolamo            Red Blend        10.0
# Anselmi                    White Blend      10.0
# Torresella                 Pinot Grigio     10.0
# Torrevento                 Primitivo        10.0
#                            Uva di Troia     10.0
# Cantina di Monteforte      Garganega        10.0
# Villa Giulia               Sangiovese        9.0
# Bolla                      White Blend       9.0
# San Giuseppe               Pinot Grigio      9.0
# Casetto                    Red Blend         9.0
# Mezzacorona                Merlot            9.0
# Tommasi                    Chardonnay        9.0
# Sorelli                    Red Blend         8.0
# Mezzacorona                Chardonnay        8.0
# Teanum                     Rosato            8.0
# La Villa Veneta            Pinot Grigio      8.0
# Galadino                   Red Blend         7.0
# La Francesca               Pinot Grigio      6.0
#
# [2317 rows x 1 columns]
# ------------------------------------
# Spain
# ------------------------------------
#                                 Price  Points      Ratio
# Variety
# Shiraz                              7      85  12.142857
# Champagne Blend                     8      85  10.625000
# Verdejo-Sauvignon Blanc            10      84   8.400000
# Airen                              10      82   8.200000
# Garnacha-Tempranillo               11      87   7.909091
# Malvasia                           11      84   7.636364
# Tempranillo-Shiraz                 12      87   7.250000
# Chardonnay-Sauvignon Blanc         12      87   7.250000
# Macabeo-Chardonnay                 12      85   7.083333
# Tempranillo-Merlot                 12      84   7.000000
# Malvar                             12      81   6.750000
# Moscato                            13      84   6.461538
# Viura-Verdejo                      13      83   6.384615
# Viura-Chardonnay                   14      87   6.214286
# Bordeaux-style Red Blend           15      87   5.800000
# Grenache Blend                     15      86   5.733333
# Sauvignon Blanc-Chardonnay         15      84   5.600000
# Garnacha-Monastrell                16      89   5.562500
# Monastrell-Petit Verdot            16      87   5.437500
# Rhône-style Red Blend              16      85   5.312500
# Tempranillo-Garnacha               17      89   5.235294
# Verdosilla                         17      84   4.941176
# Cabernet Sauvignon-Tempranillo     18      88   4.888889
# Treixadura                         18      87   4.833333
# Merlot-Cabernet Sauvignon          18      85   4.722222
# Trepat                             19      89   4.684211
# Pinot Noir                         20      89   4.450000
# Xarel-lo                           20      88   4.400000
# Macabeo                            20      87   4.350000
# Bobal                              20      87   4.350000
# ...                               ...     ...        ...
# Garnacha Blanca                    49      91   1.857143
# Rosé                               50      92   1.840000
# Cabernet Sauvignon                 55      93   1.690909
# Garnacha-Cariñena                  57      93   1.631579
# Doña Blanca                        53      84   1.584906
# Albariño                           60      91   1.516667
# Godello                            62      90   1.451613
# Carignan-Grenache                  65      92   1.415385
# Chardonnay                         65      91   1.400000
# Tempranillo-Cabernet Sauvignon     80      93   1.162500
# Sparkling Blend                    80      92   1.150000
# Viura                              80      90   1.125000
# Monastrell                         88      97   1.102273
# Tinto del Pais                     85      92   1.082353
# Tinto Fino                         90      95   1.055556
# Cabernet Blend                     90      92   1.022222
# White Blend                        95      93   0.978947
# Palomino                          100      92   0.920000
# Mazuelo                           105      91   0.866667
# Maturana                          105      88   0.838095
# Mencía                            113      93   0.823009
# Graciano                          120      92   0.766667
# Sherry                            170      94   0.552941
# Tinta de Toro                     219      95   0.433790
# Red Blend                         250      96   0.384000
# Pedro Ximénez                     258      96   0.372093
# Garnacha                          290      95   0.327586
# Tempranillo Blend                 350      96   0.274286
# Tempranillo                       600      97   0.161667
# Carignan                          770      96   0.124675
#
# [89 rows x 3 columns]
# ------------------------------------
#                                                            Price
# Winery                     Variety
# Marco Abella               Carignan                        770.0
# Terroir Al Límit           Garnacha                        290.0
# Marco Abella               Garnacha                        255.0
# Bodegas Roda               Tempranillo                     250.0
# Finca Allende              Tempranillo Blend               248.0
# Bodegas Hidalgo            Pedro Ximénez                   149.0
# Gratallops                 Red Blend                       130.0
# Matarromera                Red Blend                       125.0
# Bodegas Hidalgo            Sherry                          120.0
# Dinastía Vivanco           Graciano                        117.5
# Raúl Pérez                 Mencía                          113.0
# L'Arbossar                 Red Blend                       112.0
# Altos del Terral           Tempranillo                     110.0
# Ferrer Bobet               Carignan                        105.0
# Val Sotillo                Red Blend                       100.0
# Legaris                    Tempranillo                     100.0
# Artadi                     Tempranillo Blend               100.0
# Bodegas Dios Baco S.L.     Palomino                        100.0
# Dinastía Vivanco           Maturana                         97.5
#                            Garnacha                         95.0
# Marco Abella               White Blend                      95.0
# Bodegas Valdemar           Graciano                         95.0
# Pujanza                    Tempranillo Blend                95.0
# Dinastía Vivanco           Mazuelo                          95.0
# Campo Eliseo               Tinta de Toro                    92.5
# Pago de Carraovejas        Red Blend                        91.0
# Terroir Al Límit           Carignan                         90.0
# Convento San Francisco     Tempranillo Blend                90.0
# Clos Mogador               Red Blend                        90.0
# Marques de Griñon          Cabernet Blend                   90.0
# ...                                                          ...
# Chispas                    Garnacha                          8.0
# Grandes Vinos y Viñedos    Garnacha                          8.0
# Bodegas la Aldea           Monastrell                        8.0
# Bodegas Aragonesas         Garnacha-Tempranillo              8.0
#                            Garnacha                          8.0
# Grandes Vinos y Viñedos    Tempranillo                       8.0
# Coto de Hayas              Red Blend                         8.0
# J. Garcia Carrion          Sparkling Blend                   8.0
#                            White Blend                       8.0
#                            Moscato                           8.0
# Vicente Gandia             Cabernet Sauvignon                8.0
# Bodegas San Martín         Red Blend                         8.0
# El Prado                   Tempranillo-Cabernet Sauvignon    8.0
# Montecillo                 White Blend                       8.0
# Bodegas Luzón              Macabeo                           8.0
# Bodegas Los Llanos         Red Blend                         8.0
# Dominio de Eguren          White Blend                       7.0
#                            Rosado                            7.0
# J. Garcia Carrion          Shiraz                            7.0
# Campos Reales              Rosé                              7.0
# Dominio de Eguren          Rosé                              7.0
# Abrazo                     Garnacha                          6.5
# Campos Reales              Tempranillo                       6.5
# J. Garcia Carrion          Tempranillo                       6.0
# Bodega Virgen de la Sierra Garnacha                          6.0
# René Barbier               Tempranillo-Merlot                6.0
#                            White Blend                       6.0
# Iranzo Fields              Rosé                              6.0
# Felix Solis                Syrah                             4.0
#                            White Blend                       4.0
#
# [957 rows x 1 columns]
# ------------------------------------
# US
# ------------------------------------
#                                 Price  Points     Ratio
# Variety
# Diamond                            10      86  8.600000
# Symphony                           12      88  7.333333
# Piquepoul Blanc                    13      88  6.769231
# Valvin Muscat                      13      87  6.692308
# Moscato Giallo                     16      94  5.875000
# Melon                              15      88  5.866667
# Johannisberg Riesling              15      88  5.866667
# Touriga Nacional Blend             16      93  5.812500
# Morio Muskat                       16      90  5.625000
# Chenin Blanc-Viognier              16      90  5.625000
# Semillon-Chardonnay                15      84  5.600000
# Siegerrebe                         15      84  5.600000
# Pinot Blanc-Pinot Noir             16      85  5.312500
# Cabernet-Shiraz                    17      86  5.058824
# Traminette                         18      89  4.944444
# Cabernet Sauvignon-Tempranillo     18      87  4.833333
# Madeleine Angevine                 18      86  4.777778
# Alvarelhão                         18      85  4.722222
# Verdejo                            19      89  4.684211
# Pinot Blanc-Viognier               19      87  4.578947
# Marquette                          19      86  4.526316
# Pinot Gris-Gewürztraminer          20      90  4.500000
# Cayuga                             19      85  4.473684
# Alvarinho                          19      84  4.421053
# Cabernet Franc-Lemberger           20      88  4.400000
# Cabernet Merlot                    20      88  4.400000
# Muscat Blanc à Petits Grains       20      87  4.350000
# Pinot Auxerrois                    22      89  4.045455
# Muskat Ottonel                     22      89  4.045455
# Müller-Thurgau                     22      88  4.000000
# ...                               ...     ...       ...
# Cabernet Sauvignon-Merlot          95      96  1.010526
# Rhône-style Red Blend              95      96  1.010526
# Merlot-Cabernet Sauvignon          95      94  0.989474
# Zinfandel                         100      97  0.970000
# Cabernet Blend                     95      92  0.968421
# Cabernet Sauvignon-Syrah          100      96  0.960000
# Tempranillo                       100      95  0.950000
# Barbera                           100      93  0.930000
# Dolcetto                          100      92  0.920000
# Petite Sirah                      115      95  0.826087
# Grenache                          120      97  0.808333
# Petit Verdot                      120      94  0.783333
# Chardonnay                        130      98  0.753846
# Cabernet Franc-Merlot             125      93  0.744000
# Cabernet Franc                    140      94  0.671429
# Claret                            140      92  0.657143
# Mission                           140      90  0.642857
# Rosé                              150      96  0.640000
# Malbec                            150      95  0.633333
# Sangiovese                        150      94  0.626667
# Champagne Blend                   175      97  0.554286
# Red Blend                         185      97  0.524324
# Riesling                          200      96  0.480000
# Merlot                            200      96  0.480000
# Tannat                            200      94  0.470000
# Sparkling Blend                   250      98  0.392000
# Pinot Noir                        275      98  0.356364
# Bordeaux-style Red Blend          350      99  0.282857
# Cabernet Sauvignon                625      99  0.158400
# Syrah                             750     100  0.133333
#
# [224 rows x 3 columns]
# ------------------------------------
#                                                Price
# Winery               Variety
# Yao Ming             Cabernet Sauvignon        387.5
# Patrimony            Cabernet Sauvignon        275.0
# Joseph Phelps        Bordeaux-style Red Blend  250.0
# Nathaniel Rose       Cabernet Sauvignon        250.0
# Alpha Omega          Cabernet Sauvignon        250.0
# Silverback           Syrah                     240.0
# Continuum            Bordeaux-style Red Blend  225.0
# Heitz                Cabernet Sauvignon        225.0
# Hourglass            Bordeaux-style Red Blend  220.0
# Diamond Creek        Cabernet Sauvignon        212.5
# Alpha Omega          Bordeaux-style Red Blend  205.0
# JCB                  Cabernet Sauvignon        200.0
# M by Michael Mondavi Cabernet Sauvignon        200.0
# Newton               Cabernet Sauvignon        190.0
# Mithra               Cabernet Sauvignon        190.0
# Tuck Beckstoffer     Cabernet Sauvignon        190.0
# Merryvale            Bordeaux-style Red Blend  187.5
# Crown Point          Cabernet Sauvignon        185.0
#                      Red Blend                 185.0
# Episode              Bordeaux-style Red Blend  185.0
# Caymus               Cabernet Sauvignon        180.0
# Pahlmeyer            Red Blend                 175.0
# Stewart              Cabernet Sauvignon        175.0
# Paul Hobbs           Cabernet Sauvignon        175.0
# Delectus             Red Blend                 165.0
# Yao Family Wines     Cabernet Sauvignon        162.5
# Jarvis               Bordeaux-style Red Blend  162.5
# Merus                Cabernet Sauvignon        160.0
# Rocca                Bordeaux-style Red Blend  160.0
# Steven Kent          Red Blend                 155.0
# ...                                              ...
# Tagaris              Johannisberg Riesling       7.5
# Hogue                Red Blend                   7.5
# CK Mondavi           Pinot Grigio                7.0
# Domino               Pinot Grigio                7.0
# Tucker               Gewürztraminer              7.0
# Les Bourgeois        Rosé                        7.0
# Columbia Crest       Johannisberg Riesling       7.0
# CK Mondavi           Cabernet Sauvignon          7.0
#                      Bordeaux-style Red Blend    7.0
#                      Sauvignon Blanc             7.0
# Ste. Chapelle        Riesling                    7.0
# Castello di Borghese White Blend                 7.0
# Pontin del Roza      Chenin Blanc                7.0
# Kiona                White Riesling              7.0
# Montinore            Müller-Thurgau              7.0
# Hogue                Chenin Blanc                7.0
# Bully Hill           White Blend                 7.0
# Domino               Merlot                      7.0
# Kiona                Muscat                      7.0
# Two Vines            Riesling                    6.0
#                      Gewürztraminer              6.0
# Ste. Chapelle        Chenin Blanc                6.0
# Barefoot Cellars     Zinfandel                   6.0
# Ste. Chapelle        Gewürztraminer              6.0
#                      Johannisberg Riesling       6.0
# Two Vines            Chardonnay                  6.0
# Earth's Harvest      Merlot                      5.0
#                      Chardonnay                  5.0
# Rascal               Riesling                    5.0
# Dancing Coyote       White Blend                 4.0
#
# [12241 rows x 1 columns]
# ------------------------------------

# %%
def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*h, '%f'%h,
                ha='center', va='bottom', rotation = 'vertical')

x_axis = np.arange(len(countries))
legend_labels = ['First', 'Second', 'Third', 'Fourth', 'Fifth', 'Sixth']

y_axis_t = []
for index, country in enumerate(bar_data): 
    y_axis_t.append(bar_data[country])
y_axis_t = tuple(y_axis_t)
y_axis_arr = np.column_stack(y_axis_t)

fig, ax = plt.subplots(figsize=(10,7.5))

box = []

for ind in range(3):
    box.append(ax.bar(x_axis + (bar_width * (ind + 7)),
                       y_axis_arr[ind], bar_width, 
                       color=colors[ind], alpha = alp))


ax.set_xlabel('Countries')
ax.set_ylabel('Price to Points (Ratio)')
ax.set_title('Points per Money spent')
ax.set_xticks(x_axis + bar_width * 8)
ax.set_xticklabels(('Australia', 'Canada', 'France', 'Italy', 'Spain', 'US'))

ax.legend((box[0][0], box[1][0], box[2][0]), legend_labels)

for ind in range(3):
    autolabel(box[ind])

# %%
pricing_by_winery_data = {}
for country in countries: 
    file_name = 'output_' + country + '.xlsx'
    datatrame_list = []
    c_data = pd.read_excel(file_name)
    
    c_data = c_data.rename(index= str, columns={'title':'Title', 'description': 'Description',
                                                'taster_name': 'Sommelier', 'taster_twitter_handle':'Sommelier Twitter Acc.',
                                                'points': 'Points', 'price':"Price", 'variety': 'Variety', 'winery': 'Winery',
                                                'province':'State', 'region_1': 'County', 'latitude': 'Lat', 'longitude': "Lng",
                                                'g_address': 'Address'})
    median_price_by_winery_df = c_data.groupby(['Winery'])['Price'].median().to_frame()
    median_price_by_winery_df = median_price_by_winery_df.sort_values(by=["Price"], ascending = False)
    pricing_by_winery_data.update({country: datatrame_list})
    
    print(median_price_by_winery_df.head(10))
    
    price_by_winery = median_price_by_winery_df.reset_index()['Price'].tolist()
    price_by_winery = [round(float(x), 2) for x in price_by_winery[0:3]]
    print(f'{country}: {price_by_winery}')
    bar_data[country] = price_by_winery
# Out:
#                   Price
# Winery
# Cloudburst        225.0
# Standish          135.0
# Giaconda          112.5
# Andrew Hardy      105.0
# Torbreck          105.0
# Casella           100.0
# Heathcote Estate   95.0
# Yarra Yering       90.0
# Jasper Hill        85.0
# Apogee             80.0
# Australia: [225.0, 135.0, 112.5]
#                        Price
# Winery
# Wayne Gretzky Estates   95.0
# Peller                  87.5
# Inniskillin             80.0
# Equifera                70.0
# Stratus                 70.0
# Reif Estate             50.0
# Mission Hill            50.0
# Le Vieux Pin            45.0
# CedarCreek              45.0
# Foxtrot                 44.0
# Canada: [95.0, 87.5, 80.0]
#                                 Price
# Winery
# Château les Ormes Sorbet       3300.0
# Domaine du Comte Liger-Belair  1562.5
# Château Laville Haut-Brion      580.0
# Château La Mission Haut-Brion   524.0
# Domaine Leflaive                500.5
# Château Cheval Blanc            500.0
# Château Haut-Brion              497.5
# Château Latour                  456.0
# Armand de Brignac               450.0
# Salon                           435.0
# France: [3300.0, 1562.5, 580.0]
#                         Price
# Winery
# Masseto                 587.5
# Gaja                    450.0
# Salvioni                254.5
# Zymè                    250.0
# Giacomo Conterno        225.0
# Biondi Santi            200.0
# Bruno Giacosa           200.0
# Tenuta di Trinoro       170.0
# G.A. Rossi di Medelana  160.0
# Elio Grasso             160.0
# Italy: [587.5, 450.0, 254.5]
#                   Price
# Winery
# Bodegas Roda      160.0
# Gratallops        130.0
# Bodegas Hidalgo   120.0
# L'Arbossar        112.0
# Altos del Terral  110.0
# Artadi            100.0
# Campo Eliseo       92.5
# Pujanza            92.0
# Clos Mogador       90.0
# Raúl Pérez         87.5
# Spain: [160.0, 130.0, 120.0]
#                       Price
# Winery
# Yao Ming              387.5
# Patrimony             275.0
# Alpha Omega           250.0
# Continuum             225.0
# Diamond Creek         212.5
# M by Michael Mondavi  200.0
# Mithra                190.0
# Crown Point           185.0
# Episode               185.0
# Caymus                180.0
# US: [387.5, 275.0, 250.0]

# %%
y_axis_t = []
for index, country in enumerate(bar_data): 
    y_axis_t.append(bar_data[country])
y_axis_t = tuple(y_axis_t)
y_axis_arr = np.column_stack(y_axis_t)

fig, ax = plt.subplots(figsize=(10,7.5))

box = []

for ind in range(3):
    box.append(ax.bar(x_axis + (bar_width * (ind + 7)),
                       y_axis_arr[ind], bar_width, 
                       color=colors[ind], alpha = alp))


ax.set_xlabel('Countries')
ax.set_ylabel('Price')
ax.set_title('Top 3 Wineries by Price and Country')
ax.set_xticks(x_axis + bar_width * 8)
ax.set_xticklabels(('Australia', 'Canada', 'France', 'Italy', 'Spain', 'US'))

ax.legend((box[0][0], box[1][0], box[2][0]), legend_labels)

for ind in range(3):
    autolabel(box[ind])

# %%
scoring_by_winery_data = {}
for country in countries: 
    file_name = 'output_' + country + '.xlsx'
    datatrame_list = []
    c_data = pd.read_excel(file_name)
    
    c_data = c_data.rename(index= str, columns={'title':'Title', 'description': 'Description',
                                                'taster_name': 'Sommelier', 'taster_twitter_handle':'Sommelier Twitter Acc.',
                                                'points': 'Points', 'price':"Price", 'variety': 'Variety', 'winery': 'Winery',
                                                'province':'State', 'region_1': 'County', 'latitude': 'Lat', 'longitude': "Lng",
                                                'g_address': 'Address'})
    median_points_by_winery_df = c_data.groupby(['Winery'])['Points'].median().to_frame()
    median_points_by_winery_df = median_points_by_winery_df.sort_values(by=["Points"], ascending = False)
    scoring_by_winery_data.update({country: datatrame_list})
    
    print(median_points_by_winery_df.head(10))
    
    points_by_winery = median_points_by_winery_df.reset_index()['Points'].tolist()
    points_by_winery = [round(float(x), 2) for x in points_by_winery[0:3]]
    print(f'{country}: {points_by_winery}')
    bar_data[country] = points_by_winery
# Out:
#                  Points
# Winery
# Standish           97.0
# Tolpuddle          94.0
# Hickinbotham       94.0
# Giaconda           93.5
# Eldridge Estate    93.0
# John's Blend       93.0
# Casella            93.0
# Cherubino          93.0
# Kay Brothers       93.0
# Kalleske           92.0
# Australia: [97.0, 94.0, 94.0]
#                        Points
# Winery
# Le Vieux Pin             93.0
# Vanessa                  92.5
# Kettle Valley            92.0
# Vista d'Oro              92.0
# Tantalus                 92.0
# Stratus                  92.0
# Laughing Stock           92.0
# LaStella                 92.0
# Wayne Gretzky Estates    92.0
# CedarCreek               92.0
# Canada: [93.0, 92.5, 92.0]
#                       Points
# Winery
# Clos de Tart            98.0
# Salon                   97.5
# Domaine Leflaive        97.0
# J.L. Chave              97.0
# Barons de Rothschild    96.0
# Domaine Jean Grivot     96.0
# Domaine des Lambrays    96.0
# Château Cheval Blanc    96.0
# Château Haut-Brion      95.5
# Vieux Château Certan    95.5
# France: [98.0, 97.5, 97.0]
#                               Points
# Winery
# Masseto                         95.5
# Il Colle                        95.5
# Biondi Santi                    95.0
# Mascarello Giuseppe e Figlio    95.0
# Guido Porro                     95.0
# Bruno Giacosa                   95.0
# L'Aietta                        95.0
# Schiavenza                      95.0
# Giuseppe Rinaldi                95.0
# Cantina Bartolo Mascarello      94.5
# Italy: [95.5, 95.5, 95.0]
#                    Points
# Winery
# Campo Eliseo         95.0
# Clos Mogador         94.0
# Bodegas Roda         94.0
# Dominio de Berzal    93.5
# Bodegas Hidalgo      93.0
# Hidalgo              93.0
# Bodega del Abad      93.0
# Sangenís I Vaqué     93.0
# San Vicente          93.0
# Emilio Rojo          93.0
# Spain: [95.0, 94.0, 94.0]
#                   Points
# Winery
# Alpha Omega         97.5
# Patrimony           96.0
# D'Alfonso-Curran    96.0
# Crown Point         95.5
# Herman Story        95.0
# Portfolio           95.0
# Wayfarer            95.0
# DAOU                95.0
# Horsepower          95.0
# La Jota Vineyard    95.0
# US: [97.5, 96.0, 96.0]

# %%
y_axis_t = []
for index, country in enumerate(bar_data): 
    y_axis_t.append(bar_data[country])
y_axis_t = tuple(y_axis_t)
y_axis_arr = np.column_stack(y_axis_t)

fig, ax = plt.subplots(figsize=(10,7.5))

box = []

for ind in range(3):
    box.append(ax.bar(x_axis + (bar_width * (ind + 7)),
                       y_axis_arr[ind], bar_width, 
                       color=colors[ind], alpha = alp))


ax.set_xlabel('Countries')
ax.set_ylabel('Points by Sommelier')
ax.set_title('Top 3 Wineries by Points and Country')
ax.set_xticks(x_axis + bar_width * 8)
ax.set_xticklabels(('Australia', 'Canada', 'France', 'Italy', 'Spain', 'US'))
ax.set_ylim(75, 105)

ax.legend((box[0][0], box[1][0], box[2][0]), legend_labels)

for ind in range(3):
    autolabel(box[ind])

# %%
scoring_by_variety_data = {}
for country in countries: 
    file_name = 'output_' + country + '.xlsx'
    datatrame_list = []
    c_data = pd.read_excel(file_name)
    
    c_data = c_data.rename(index= str, columns={'title':'Title', 'description': 'Description',
                                                'taster_name': 'Sommelier', 'taster_twitter_handle':'Sommelier Twitter Acc.',
                                                'points': 'Points', 'price':"Price", 'variety': 'Variety', 'winery': 'Winery',
                                                'province':'State', 'region_1': 'County', 'latitude': 'Lat', 'longitude': "Lng",
                                                'g_address': 'Address'})
    median_points_by_variety_df = c_data.groupby(['Variety'])['Points'].median().to_frame()
    median_points_by_variety_df = median_points_by_variety_df.sort_values(by=["Points"], ascending = False)
    scoring_by_variety_data.update({country: datatrame_list})
    
    print(median_points_by_variety_df.head(10))
    
    top_wineries_by_variety = median_points_by_variety_df.reset_index()['Variety'].tolist()
    top_wineries_by_variety = top_wineries_by_variety[0:10]
    
    points_by_variety = median_points_by_variety_df.reset_index()['Points'].tolist()
    points_by_variety = [round(float(x), 2) for x in points_by_variety[0:3]]
    print(f'{country}: {points_by_variety}')
    bar_data[country] = points_by_variety
# Out:
#                                   Points
# Variety
# Cabernet-Shiraz                     96.0
# Mourvèdre-Syrah                     92.0
# Syrah                               92.0
# Mataro                              91.5
# Cabernet Sauvignon-Shiraz           91.5
# Shiraz-Grenache                     91.5
# Mourvèdre                           91.5
# Muscat                              91.0
# Cabernet Sauvignon-Merlot-Shiraz    91.0
# Shiraz-Viognier                     90.5
# Australia: [96.0, 92.0, 92.0]
#                           Points
# Variety
# Moscato                     92.0
# Malbec                      92.0
# Meritage                    91.5
# Red Blend                   91.0
# Bordeaux-style Red Blend    91.0
# Muscat                      91.0
# Cabernet Sauvignon          91.0
# Vidal                       91.0
# Gewürztraminer              90.5
# Syrah                       90.5
# Canada: [92.0, 92.0, 91.5]
#                     Points
# Variety
# Mourvèdre             93.0
# Alsace white blend    92.0
# Savagnin              92.0
# Sauvignon             92.0
# Petit Verdot          92.0
# Petit Manseng         92.0
# Grenache Blanc        91.5
# Roussanne-Marsanne    91.0
# Romorantin            91.0
# Riesling              91.0
# France: [93.0, 92.0, 92.0]
#                            Points
# Variety
# Cabernet Sauvignon-Merlot    95.0
# Roviello                     93.0
# Zibibbo                      92.0
# Cabernet Franc               92.0
# Corvina                      92.0
# Caprettone                   92.0
# Carignano                    92.0
# Torbato                      91.0
# Nerello Cappuccio            90.5
# Nasco                        90.5
# Italy: [95.0, 93.0, 92.0]
#                    Points
# Variety
# Tinta del Pais       95.0
# Carignan             94.0
# Garnacha-Cariñena    93.0
# Carignan-Grenache    92.0
# Pedro Ximénez        91.0
# Petit Verdot         91.0
# Sherry               90.5
# Mencía               90.0
# Mataro               90.0
# Palomino             90.0
# Spain: [95.0, 94.0, 93.0]
#                                 Points
# Variety
# Riesling-Chardonnay               94.0
# Moscato Giallo                    94.0
# Mourvèdre-Syrah                   94.0
# Syrah-Petit Verdot                94.0
# Tannat-Syrah                      93.0
# Trousseau Gris                    93.0
# Touriga Nacional Blend            93.0
# Syrah-Viognier                    92.5
# Tempranillo-Cabernet Sauvignon    92.0
# Scheurebe                         91.0
# US: [94.0, 94.0, 94.0]

# %%
y_axis_t = []
for index, country in enumerate(bar_data): 
    y_axis_t.append(bar_data[country])
y_axis_t = tuple(y_axis_t)
y_axis_arr = np.column_stack(y_axis_t)

fig, ax = plt.subplots(figsize=(10, 7.5))

box = []

for ind in range(3):
    box.append(ax.bar(x_axis + (bar_width * (ind + 7)),
                       y_axis_arr[ind], bar_width, 
                       color=colors[ind], alpha = alp))


ax.set_xlabel('Countries')
ax.set_ylabel('Points')
ax.set_title('Top 3 Wineries by Varieties and Country')
ax.set_xticks(x_axis + bar_width * 8)
ax.set_xticklabels(('Australia', 'Canada', 'France', 'Italy', 'Spain', 'US'))
ax.set_ylim(75, 105)

ax.legend((box[0][0], box[1][0], box[2][0]), legend_labels)

for ind in range(3):
    autolabel(box[ind])

# %%
points_by_sommelier_data = {}

file_name = 'output.xlsx'
datatrame_list = []
c_data = pd.read_excel(file_name)

c_data = c_data.rename(index= str, columns={'title':'Title', 'description': 'Description',
                                            'taster_name': 'Sommelier', 'taster_twitter_handle':'Sommelier Twitter Acc.',
                                            'points': 'Points', 'price':"Price", 'variety': 'Variety', 'winery': 'Winery',
                                            'province':'State', 'region_1': 'County', 'latitude': 'Lat', 'longitude': "Lng",
                                            'g_address': 'Address'})
median_points_by_variety_df = c_data.groupby(['Sommelier'])['Points'].max().to_frame()
median_points_by_variety_df = median_points_by_variety_df.sort_values(by=["Points"], ascending = False)
scoring_by_variety_data.update({country: datatrame_list})

points_by_variety = median_points_by_variety_df.reset_index()['Points'].tolist()
points_by_variety = [round(float(x), 2) for x in points_by_variety[0:3]]
print(f'{country}: {points_by_variety}')
bar_data[country] = points_by_variety
# Out:
# US: [94.0, 93.0, 91.0]

# %%
import gmaps
us_df = pd.read_excel('output_France.xlsx')
us_df
locations = us_df[["latitude", "longitude"]]
rating = us_df["points"].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating,
                                dissipating=False, max_intensity=0,
                                point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
us_df = pd.read_excel('output_Spain.xlsx')
us_df
locations = us_df[["latitude", "longitude"]]
rating = us_df["points"].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating,
                                dissipating=False, max_intensity=0,
                                point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
us_df = pd.read_excel('output_Italy.xlsx')
us_df
locations = us_df[["latitude", "longitude"]]
rating = us_df["points"].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating,
                                dissipating=False, max_intensity=0,
                                point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
us_df = pd.read_excel('output_US.xlsx')
us_df
locations = us_df[["latitude", "longitude"]]
rating = us_df["points"].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating,
                                dissipating=False, max_intensity=0,
                                point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
us_df = pd.read_excel('output_Canada.xlsx')
us_df
locations = us_df[["latitude", "longitude"]]
rating = us_df["points"].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating,
                                dissipating=False, max_intensity=0,
                                point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
us_df = pd.read_excel('output_Australia.xlsx')
us_df
locations = us_df[["latitude", "longitude"]]
rating = us_df["points"].astype(float)
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating,
                                dissipating=False, max_intensity=0,
                                point_radius=1)

# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
